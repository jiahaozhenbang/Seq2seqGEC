# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_data(data, c='c', label='', bins=100):
    plt.subplot(1, 1, 1)
    plt.hist(data,bins=bins, label='')
    plt.xticks(np.arange(0,1,0.05))
    plt.legend()
    plt.show()

# %%
stage1_entropy = '/home/ljh/GEC/Seq2seqGEC/preprocess/stage2_en/train0411.entropy.npz'
entropy_dict = dict(np.load(stage1_entropy))

# %%
def get_quality(data, i):
    if 'lengths' in data:
        output = data['data'][i]
        length = data['lengths'][i]
        return output[:length]
    else:
        return data['arr_' + str(i)]

# %%
def convert_entropy(entro):
    SCALE_CONSTANT = 9
    CONSTANT= np.exp(-SCALE_CONSTANT)
    converted = - np.log(entro + CONSTANT) / SCALE_CONSTANT
    converted = np.where(converted > CONSTANT, converted, CONSTANT)
    sentence_entropy = np.mean(converted)
    return sentence_entropy

sent_entropy = []
for i in range(100000):
    data = get_quality(entropy_dict, i)
    data = convert_entropy(data)
    sent_entropy.append(data)

# %%
print(len(sent_entropy))
sample_data = sent_entropy[:100000]
# Out:
# 100000

# %%
plt.figure(figsize=(20, 8))
plot_data(sample_data)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def convert_entropy(entro):
    SCALE_CONSTANT = 9
    CONSTANT= np.exp(-SCALE_CONSTANT)
    converted = - np.log(entro + CONSTANT) / SCALE_CONSTANT
    converted = np.where(converted > CONSTANT, converted, CONSTANT)
    sentence_entropy = np.min(converted)
    return sentence_entropy

sent_entropy = []
for i in range(100000):
    data = get_quality(entropy_dict, i)
    data = convert_entropy(data)
    sent_entropy.append(data)
sample_data = sent_entropy[:100000]
plt.figure(figsize=(20, 8))
plot_data(sample_data)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
min(sample_data)
# Out:
# 0.00502550174987241

# %%
print(entropy_dict['data'][entropy_dict['data'] > 0].min())
print(entropy_dict['data'][entropy_dict['data'] > 0].max())
# Out:
# 0.00010022285277955234
# 0.9826365113258362

# %%
for i in range(30):
    data = get_quality(entropy_dict, i)
    print(data)
# Out:
# [0.08501316 0.42841136 0.10760735]
# [0.11455927 0.12174848 0.11320972 0.10884795 0.18084741 0.08899801
#  0.10429707]
# [0.10957047 0.17116778 0.17574692 0.13279748 0.13190854 0.12155256
#  0.23700073 0.12476505 0.15193704 0.09055901 0.09703407]
# [0.13235722 0.11397308 0.11031019 0.13501385 0.11765096 0.17024672
#  0.18568529 0.10277867 0.10714927 0.12119973 0.12513307 0.08519569
#  0.10628908]
# [0.10803208 0.11462976 0.1534524  0.10705151 0.15115368 0.11299086
#  0.12713048 0.26596925 0.12945925 0.11864074 0.14466357 0.11940794
#  0.17072317 0.0653016  0.10429146 0.17816639 0.08364404 0.10767172]
# [0.12688236 0.10998656 0.13763729 0.11998729 0.09890436 0.10665061
#  0.12061459 0.13961333 0.11124818 0.11796617 0.10238886 0.16076687
#  0.14633466 0.1084386  0.10039166 0.09341688 0.10935798]
# [0.22963108 0.33090982 0.10042433 0.11232915 0.08473708 0.10306276
#  0.09056342]
# [0.07210695 0.12579867 0.11174979 0.14725    0.1291481  0.12111667
#  0.17237289 0.15119863 0.14068338 0.16953973 0.11862021 0.13327664
#  0.12755351 0.12426457 0.12767893 0.16905172 0.11736638 0.27148739
#  0.15548886 0.15320322 0.099061  ]
#  0.12319787 0.18764593 0.09442508 0.09738822]
# [0.13094722 0.14630418 0.12565991 0.13209917 0.15983337 0.22524118
#  0.1250636  0.12389492 0.09046995 0.55108517 0.12061591 0.10075704
#  0.12856683 0.11284611 0.11951933 0.10687287 0.13057548 0.09015613
#  0.10459875]
# [0.09214924 0.10741314 0.12429335 0.09901693 0.13779898 0.09788609
#  0.10365939]
# [0.13884822 0.23083183 0.10054509 0.13541259 0.23514682 0.1892506
#  0.10594243 0.09836122 0.09107716 0.11052895]
# [0.06364352 0.57721251 0.14231692 0.29305983 0.09332488 0.10287702]

# %%
entropy_list = []
for i in range(10000):
    data = get_quality(entropy_dict, i)
    entropy_list.extend(data)
def plot_entropy(data, c='c', label='', bins=100):
    plt.subplot(1, 1, 1)
    plt.hist(data,bins=bins, label='')
    plt.xticks(np.arange(0,1,0.05))
    plt.legend()
    plt.show()
plt.figure(figsize=(20, 8))
plot_entropy(entropy_list)
print(np.mean(entropy_list))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.13909418243915422

# %%
for i in range(10):
    print(i, np.percentile(entropy_list, i))
# Out:
# 0 0.0032224655151367188
# 1 0.06017463214695454
# 2 0.07217551365494729
# 3 0.07916473060846328
# 4 0.08308720707893372
# 5 0.0858106840401888
# 6 0.0878789958357811
# 7 0.08964213609695434
# 8 0.09105774700641632
# 9 0.09233985953032971

# %%
def convert_entropy(entro):
    SCALE_CONSTANT = 4
    CONSTANT= np.exp(-SCALE_CONSTANT)
    converted = - np.log(entro + CONSTANT) / SCALE_CONSTANT
    converted = np.where(converted > CONSTANT, converted, CONSTANT)
    sentence_entropy = np.mean(converted)
    return sentence_entropy

sent_entropy = []
for i in range(100000):
    data = get_quality(entropy_dict, i)
    data = convert_entropy(data)
    sent_entropy.append(data)
sample_data = sent_entropy[:100000]
plt.figure(figsize=(20, 8))
plot_data(sample_data)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def convert_entropy(entro):
    SCALE_CONSTANT = 4
    CONSTANT= np.exp(-SCALE_CONSTANT)
    converted = - np.log(entro + CONSTANT) / SCALE_CONSTANT
    converted = np.where(converted > CONSTANT, converted, CONSTANT)
    sentence_entropy = np.min(converted)
    return sentence_entropy
def get_quality(data, i):
    if 'lengths' in data:
        output = data['data'][i]
        length = data['lengths'][i]
        return output[:length]
    else:
        return data['arr_' + str(i)]
sent_entropy = []
for i in range(100000):
    data = get_quality(entropy_dict, i)
    data = convert_entropy(data)
    sent_entropy.append(data)
sample_data = sent_entropy[:100000]
plt.figure(figsize=(20, 8))
plot_data(sample_data)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def convert_entropy(entro):
    SCALE_CONSTANT = 3
    CONSTANT= np.exp(-SCALE_CONSTANT)
    converted = - np.log(entro + CONSTANT) / SCALE_CONSTANT
    converted = np.where(converted > CONSTANT, converted, CONSTANT)
    sentence_entropy = np.min(converted)
    return sentence_entropy
sent_entropy = []
for i in range(100000):
    data = get_quality(entropy_dict, i)
    data = convert_entropy(data)
    sent_entropy.append(data)
sample_data = sent_entropy[:100000]
plt.figure(figsize=(20, 8))
plot_data(sample_data)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def convert_entropy(entro):
    SCALE_CONSTANT = 3
    CONSTANT= np.exp(-SCALE_CONSTANT)
    converted = - np.log(entro + CONSTANT) / SCALE_CONSTANT
    converted = np.where(converted > CONSTANT, converted, CONSTANT)
    sentence_entropy = np.mean(converted)
    return sentence_entropy
sent_entropy = []
for i in range(100000):
    data = get_quality(entropy_dict, i)
    data = convert_entropy(data)
    sent_entropy.append(data)
sample_data = sent_entropy[:100000]
plt.figure(figsize=(20, 8))
plot_data(sample_data)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def convert_entropy(entro):
    SCALE_CONSTANT = 3
    CONSTANT= np.exp(-SCALE_CONSTANT)
    converted = - np.log(entro + CONSTANT) / SCALE_CONSTANT
    converted = np.where(converted > CONSTANT, converted, CONSTANT)
    sentence_entropy = np.min(converted)
    return sentence_entropy
sent_entropy = []
for i in range(100000):
    data = get_quality(entropy_dict, i)
    data = convert_entropy(data)
    sent_entropy.append(data)
sample_data = sent_entropy[:100000]
plt.figure(figsize=(20, 8))
plot_data(sample_data)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def convert_entropy(entro):
    SCALE_CONSTANT = 2
    CONSTANT= np.exp(-SCALE_CONSTANT)
    converted = - np.log(entro + CONSTANT) / SCALE_CONSTANT
    converted = np.where(converted > CONSTANT, converted, CONSTANT)
    sentence_entropy = np.min(converted)
    return sentence_entropy
def get_quality(data, i):
    if 'lengths' in data:
        output = data['data'][i]
        length = data['lengths'][i]
        return output[:length]
    else:
        return data['arr_' + str(i)]
sent_entropy = []
for i in range(100000):
    data = get_quality(entropy_dict, i)
    data = convert_entropy(data)
    sent_entropy.append(data)
sample_data = sent_entropy[:100000]
plt.figure(figsize=(20, 8))
plot_data(sample_data)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # correct

# %%
stage1_correct = '/home/ljh/GEC/Seq2seqGEC/preprocess/stage2_en/train0411.correct_probs.npz'
correct_dict = dict(np.load(stage1_correct))

# %%
def get_quality(data, i):
    if 'lengths' in data:
        output = data['data'][i]
        length = data['lengths'][i]
        return output[:length]
    else:
        return data['arr_' + str(i)]
correct = []
for i in range(100000):
    data = get_quality(correct_dict, i)
    correct.extend(data)
plt.figure(figsize=(20, 8))
plot_data(correct)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
stage1_correct = '/home/ljh/GEC/Seq2seqGEC/preprocess/wi_locness/train0413.correct_probs.npz'
correct_dict = dict(np.load(stage1_correct))
def get_quality(data, i):
    if 'lengths' in data:
        output = data['data'][i]
        length = data['lengths'][i]
        return output[:length]
    else:
        return data['arr_' + str(i)]
correct = []
for i in range(len(correct_dict['lengths'])):
    data = get_quality(correct_dict, i)
    correct.extend(data)
plt.figure(figsize=(20, 8))
plot_data(correct)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
stage1_entropy = '/home/ljh/GEC/Seq2seqGEC/preprocess/wi_locness/train0413.entropy.npz'
entropy_dict = dict(np.load(stage1_entropy))
def convert_entropy(entro):
    SCALE_CONSTANT = 3
    CONSTANT= np.exp(-SCALE_CONSTANT)
    converted = - np.log(entro + CONSTANT) / SCALE_CONSTANT
    converted = np.where(converted > CONSTANT, converted, CONSTANT)
    sentence_entropy = np.mean(converted)
    return sentence_entropy
sent_entropy = []
entropy = []
for i in range(len(entropy_dict['lengths'])):
    data = get_quality(entropy_dict, i)
    entropy.extend(data)
    data = convert_entropy(data)
    sent_entropy.append(data)
plt.figure(figsize=(20, 8))
plot_data(sent_entropy)
plt.figure(figsize=(20, 8))
plot_data(entropy)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
